# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from mlxtend.frequent_patterns import apriori

# %%
data = pd.read_csv("sales.csv")
data.head()
# Out:
#    CustomerID  ProductID  OrderQty  OrderID
# 0       11000        771         1    43793
# 1       11000        779         1    51522
# 2       11000        878         1    51522
# 3       11000        966         1    57418
# 4       11000        934         1    57418

# %%
df = pd.DataFrame(data)

# Nhóm các ProductKey cùng SalesOrderID
data_grouped = df.groupby('OrderID')['ProductID'].apply(list)

# In kết quả
print(data_grouped)
# Out:
# OrderID
# 43659    [776, 777, 778, 771, 772, 773, 774, 714, 716, ...
# 43660                                           [762, 758]
# 43661    [745, 743, 747, 712, 715, 742, 775, 778, 711, ...
# 43662    [764, 770, 730, 754, 725, 762, 765, 768, 753, ...
# 43663                                                [760]
#                                ...
# 75119                                      [921, 930, 873]
# 75120                                      [878, 884, 712]
# 75121                                      [921, 930, 707]
# 75122                                           [878, 712]
# 75123                                      [878, 879, 712]
# Name: ProductID, Length: 31465, dtype: object

# %%
# Chuyển đổi dữ liệu group thành dạng list của list (mỗi list là một transaction)
transactions = [[str(item) for item in transaction] for transaction in data_grouped]

# Sử dụng MultiLabelBinarizer để chuyển đổi dữ liệu thành dạng mã hóa
mlb = MultiLabelBinarizer()
df_encoded = pd.DataFrame(mlb.fit_transform(transactions), columns=mlb.classes_)

# Tính toán frequent itemsets với minimum support là 0.02
frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

frequent_itemsets
# Out:
# c:\Users\N\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#        support                                           itemsets
# 0     0.097982                                              (707)
# 1     0.095567                                              (708)
# 2     0.098204                                              (711)
# 3     0.107485                                              (712)
# 4     0.013634                                              (713)
# ...        ...                                                ...
# 3401  0.010011      (876, 715, 884, 865, 883, 864, 877, 711, 712)
# 3402  0.010329      (876, 715, 884, 870, 883, 864, 877, 711, 712)
# 3403  0.010011      (876, 715, 884, 865, 870, 864, 877, 711, 883)
# 3404  0.010011      (876, 715, 884, 865, 870, 864, 877, 883, 712)
# 3405  0.010265  (876, 715, 884, 870, 883, 864, 708, 711, 877, ...
#
# [3406 rows x 2 columns]

# %%
frequent_itemsets.sort_values(by='support', ascending=False, inplace=True)
frequent_itemsets = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: len(x)) > 1]
frequent_itemsets['itemsets'] = frequent_itemsets['itemsets'].apply(list)
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_14064\2144805677.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frequent_itemsets['itemsets'] = frequent_itemsets['itemsets'].apply(list)

# %%
frequent_itemsets
# Out:
#        support                             itemsets
# 303   0.053774                           [870, 871]
# 304   0.048339                           [870, 872]
# 162   0.037248                           [715, 712]
# 177   0.032385                           [870, 712]
# 142   0.032131                           [712, 711]
# ...        ...                                  ...
# 3022  0.010011  [884, 711, 877, 864, 708, 880, 883]
# 1362  0.010011                 [880, 864, 865, 883]
# 2294  0.010011       [715, 883, 708, 711, 880, 712]
# 2296  0.010011       [858, 859, 708, 711, 716, 712]
# 1703  0.010011            [876, 708, 883, 880, 712]
#
# [3301 rows x 2 columns]

# %%
type(frequent_itemsets.iloc[0]['itemsets'])
# Out:
# list

# %%
frequent_itemsets.to_csv("frequent_itemsets.csv", index=False)

# %%
import pandas as pd
load = pd.read_csv("frequent_itemsets.csv")

# %%
# load['itemsets'] = load['itemsets'].apply(list)
load
# Out:
#        support                                           itemsets
# 0     0.053774                                     ['870', '871']
# 1     0.048339                                     ['870', '872']
# 2     0.037248                                     ['715', '712']
# 3     0.032385                                     ['870', '712']
# 4     0.032131                                     ['712', '711']
# ...        ...                                                ...
# 3296  0.010011  ['884', '711', '877', '864', '708', '880', '883']
# 3297  0.010011                       ['880', '864', '865', '883']
# 3298  0.010011         ['715', '883', '708', '711', '880', '712']
# 3299  0.010011         ['858', '859', '708', '711', '716', '712']
# 3300  0.010011                ['876', '708', '883', '880', '712']
#
# [3301 rows x 2 columns]

# %%
import ast
def predict_next_purchase(product_id):
    with open("output.txt", "r") as file:
        spade_output_lines = file.readlines()

    # Predict next purchase from SPADE output
    spade_predictions = []
    for line in spade_output_lines:
        line = line.replace("\n", "")
        line_lst = line.split(' -1 ')
        if line_lst[0] == str(product_id):
            support = int(line_lst[-1].replace("#SUP: ", ""))
            for sequence in line_lst[1:-1]:
                spade_predictions.append([sequence, support])
    top_predictions = sorted(spade_predictions, key=lambda x: x[1], reverse=True)[:10]

    frequent_itemsets = pd.read_csv("frequent_itemsets.csv")
    # Predict combination from frequent itemsets
    ar_predictions = []
    for prediction in top_predictions:
        items = prediction[0].split()
        related_itemset = set()
        for item in items:
            max_support = 0
            max_combination = None
            for index, row in frequent_itemsets.iterrows():
                lst = ast.literal_eval(row['itemsets'])
                if item in lst and len(lst) > 1:
                    if row['support'] > max_support:
                        max_support = row['support']
                        max_combination = lst
            if max_combination:
                related_itemset.update(max_combination)  
        ar_predictions.append(list(related_itemset))

    return top_predictions, ar_predictions

# %%
product_id = 793  
spade_predictions, ar_predictions = predict_next_purchase(product_id)

print("Predicted next purchase from SPADE:", spade_predictions)
print("Predicted next purchases from association rules:", ar_predictions)
# Out:
# Predicted next purchase from SPADE: []
# Predicted next purchases from association rules: []

# %%
import pyodbc 
import pandas as pd
cnxn = pyodbc.connect("Driver={ODBC Driver 17 for SQL Server};"
                      "Server=HEO;"
                      "Database=DW_Inventory;"
                      "Trusted_Connection=yes;")

# %%
cursor = cnxn.cursor()
query = """
SELECT ProductKey, ProductID
FROM Dim_Product
"""
product_list = pd.read_sql(query, cnxn)
product_list
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_19804\2235753677.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_list = pd.read_sql(query, cnxn)
#      ProductKey  ProductID
# 0             1          1
# 1             2        464
# 2             3        463
# 3             4        462
# 4             5        461
# ..          ...        ...
# 499         500        923
# 500         501        922
# 501         502        921
# 502         503        929
# 503         504        933
#
# [504 rows x 2 columns]

# %%
conn = 1
cursor = 1
cnxn = 1

# %%
import ast
import pandas as pd
import pyodbc

# Read the CSV file
df = pd.read_csv('next_purchase_predictions.csv')

# Establish connection to SQL Server
cnxn = pyodbc.connect("Driver={ODBC Driver 17 for SQL Server};"
                      "Server=HEO;"
                      "Database=DW_Inventory;"
                      "Trusted_Connection=yes;")
cursor = cnxn.cursor()

# Step 1: Insert data into the PredictedSequences table
for sequence_id, combination in enumerate(df['combination_from_next_sequence'].unique(), start=1):
    cursor.execute("INSERT INTO PredictedSequences (sequence_id, combination_from_next_sequence) VALUES (?, ?)", 
                   (sequence_id, combination))

# Step 2: Map product IDs to their corresponding keys
product_list_dict = dict(zip(product_list['ProductID'], product_list['ProductKey']))

# Step 3: Insert data into ProductSequences table
for index, row in df.iterrows():
    product_key = product_list_dict[row['productID']]
    sequence_id = index + 1  # Since sequence_id starts from 1
    combination = ast.literal_eval(row['combination_from_next_sequence'])
    
    # Insert into ProductSequences table
    cursor.execute("INSERT INTO ProductSequences (productkey, sequence_id, combination) VALUES (?, ?, ?)", 
                   (product_key, sequence_id, ','.join(map(str, combination))))

# Commit changes and close connection
cnxn.commit()
cnxn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Input In [19], in <cell line: 24>()
#      27     combination = ast.literal_eval(row['combination_from_next_sequence'])
#      29     # Insert into ProductSequences table
# ---> 30     cursor.execute("INSERT INTO ProductSequences (productkey, sequence_id, combination) VALUES (?, ?, ?)",
#      31                    (product_key, sequence_id, ','.join(map(str, combination))))
#      33 # Commit changes and close connection
#      34 cnxn.commit()
#
# ProgrammingError: ('42S22', "[42S22] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Invalid column name 'productkey'. (207) (SQLExecDirectW); [42S22] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Statement(s) could not be prepared. (8180)")

# %%
product_info = """
SELECT distinct(ProductID), ProductName from Dim_Product
"""
product_info = pd.read_sql(product_info, cnxn)
product_info
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_21392\4073179723.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_info = pd.read_sql(product_info, cnxn)
#      ProductID            ProductName
# 0            1        Adjustable Race
# 1            2           Bearing Ball
# 2            3        BB Ball Bearing
# 3            4  Headset Ball Bearings
# 4          316                  Blade
# ..         ...                    ...
# 499        995      ML Bottom Bracket
# 500        996      HL Bottom Bracket
# 501        997     Road-750 Black, 44
# 502        998     Road-750 Black, 48
# 503        999     Road-750 Black, 52
#
# [504 rows x 2 columns]

# %%
get_product_query = """
SELECT distinct(ProductID) from Dim_Product
"""
product_list = pd.read_sql_query(get_product_query, cnxn)
product_list
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_19804\455720322.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_list = pd.read_sql_query(get_product_query, cnxn)
#      ProductID
# 0            1
# 1            2
# 2            3
# 3            4
# 4          316
# ..         ...
# 499        995
# 500        996
# 501        997
# 502        998
# 503        999
#
# [504 rows x 1 columns]

# %%
product_ids = []
next_sequences = []
combinations = []

for idx, row in product_list.iterrows():
    product_id = row['ProductID']
    spade_predictions, ar_predictions = predict_next_purchase(product_id)
    
    for spade_pred, ar_pred in zip(spade_predictions, ar_predictions):
        product_ids.append(product_id)
        next_sequences.append(spade_pred[0])
        combinations.append(ar_pred)

new_df = pd.DataFrame({
    "productID": product_ids,
    "next_sequence": next_sequences,
    "combination_from_next_sequence": combinations
})
new_df
# Out:
#      productID next_sequence combination_from_next_sequence
# 0          707           712                     [715, 712]
# 1          707           711                     [711, 712]
# 2          707           707                     [712, 707]
# 3          707           708                     [708, 712]
# 4          707           715                     [715, 712]
# ..         ...           ...                            ...
# 227        884           864                     [864, 884]
# 228        884       864 884                [864, 870, 884]
# 229        921           873                     [921, 873]
# 230        921           870                     [870, 871]
# 231        930           870                     [870, 871]
#
# [232 rows x 3 columns]

# %%
new_df.to_csv("next_purchase_predictions.csv", index=False)

# %%
import pandas as pd
new_df = pd.read_csv("next_purchase_predictions.csv")

# %%
new_df['combination_from_next_sequence'] = new_df['combination_from_next_sequence'].apply(eval)

# %%
product_info.to_csv("product_info.csv", index=False)

# %%
import pandas as pd
import pyodbc
cnxn = pyodbc.connect("Driver={ODBC Driver 17 for SQL Server};"
                      "Server=SERVER CUA NGA;"
                      "Database=DW CUA NHOM;"
                      "Trusted_Connection=yes;")
new_df = pd.read_csv("next_purchase_predictions.csv")
new_df['combination_from_next_sequence'] = new_df['combination_from_next_sequence'].apply(eval)
df = new_df
product_info_qr = """
SELECT distinct(ProductID), ProductName from Dim_Product
"""
product_info = pd.read_sql(product_info_qr, cnxn)
def replace_product_names(row):
    product_ids = row["next_sequence"].split()  
    product_names = [product_info.loc[product_info["ProductID"] == int(product_id), "ProductName"].values[0] for product_id in product_ids]
    return ", ".join(product_names)

df["next_sequence"] = df.apply(replace_product_names, axis=1)

def replace_combination_names(combination_list):
    return [product_info.loc[product_info["ProductID"] == int(product_id), "ProductName"].values[0] for product_id in combination_list]

df["combination_from_next_sequence"] = df["combination_from_next_sequence"].apply(replace_combination_names)

CREATE_PREDICTION_TABLE_IF_NOT_EXIST_QUERY = """
IF NOT EXISTS (SELECT * FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_NAME = 'DimPrediction')
BEGIN
CREATE TABLE DimPrediction(
    ProductID INT,
    NextSequence VARCHAR(255),
    CombinationFromNextSequence VARCHAR(255)
);
END
"""
INSERT_PREDICTION_QUERY = """
INSERT INTO DimPrediction(ProductID, NextSequence, CombinationFromNextSequence)
VALUES (?, ?, ?)
"""
cursor = cnxn.cursor()
cursor.execute(CREATE_PREDICTION_TABLE_IF_NOT_EXIST_QUERY)
cnxn.commit()
cursor = cnxn.cursor()
for idx, row in df.iterrows():
    cursor.execute(INSERT_PREDICTION_QUERY, row['productID'], str(row['next_sequence']), str(row['combination_from_next_sequence']))
    cnxn.commit()
# Out:
# C:\Users\N\AppData\Local\Temp\ipykernel_1820\2047837451.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_info = pd.read_sql(product_info_qr, cnxn)

# %%
df.to_csv("next_purchase_predictions_formatted.csv", index=False)

# %%
CREATE_PREDICTION_TABLE_IF_NOT_EXIST_QUERY = """
IF NOT EXISTS (SELECT * FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_NAME = 'DimPrediction')
BEGIN
CREATE TABLE DimPrediction(
    ProductID INT,
    NextSequence VARCHAR(255),
    CombinationFromNextSequence VARCHAR(255)
);
END
"""
INSERT_PREDICTION_QUERY = """
INSERT INTO DimPrediction(ProductID, NextSequence, CombinationFromNextSequence)
VALUES (?, ?, ?)
"""
cursor = cnxn.cursor()
cursor.execute(CREATE_PREDICTION_TABLE_IF_NOT_EXIST_QUERY)
cnxn.commit()
cursor = cnxn.cursor()
for idx, row in df.iterrows():
    cursor.execute(INSERT_PREDICTION_QUERY, row['productID'], str(row['next_sequence']), str(row['combination_from_next_sequence']))
    cnxn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 stop
#       2 CREATE_PREDICTION_TABLE_IF_NOT_EXIST_QUERY = """
#       3 IF NOT EXISTS (SELECT * FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_NAME = 'DimPrediction')
#       4 BEGIN
#    (...)
#      10 END
#      11 """
#      12 INSERT_PREDICTION_QUERY = """
#      13 INSERT INTO DimPrediction(ProductID, NextSequence, CombinationFromNextSequence)
#      14 VALUES (?, ?, ?)
#      15 """
#
# NameError: name 'stop' is not defined

# %%
cursor = cnxn.cursor()
cursor.execute(CREATE_PREDICTION_TABLE_IF_NOT_EXIST_QUERY)
cnxn.commit()

# %%
cursor = cnxn.cursor()
for idx, row in df.iterrows():
    cursor.execute(INSERT_PREDICTION_QUERY, row['productID'], str(row['next_sequence']), str(row['combination_from_next_sequence']))
    cnxn.commit()

# %%
new_df['combination_from_next_sequence'].tolist()
# Out:
# [['715', '712'],
#  ['711', '712'],
#  ['707', '712'],
#  ['708', '712'],
#  ['715', '712'],
#  ['870', '871'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['711', '712'],
#  ['707', '712'],
#  ['708', '712'],
#  ['870', '871'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['711', '712'],
#  ['708', '712'],
#  ['707', '712'],
#  ['715', '712'],
#  ['870', '871'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['711', '712'],
#  ['708', '712'],
#  ['707', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['870', '871'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['711', '712'],
#  ['715', '712'],
#  ['708', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['707', '712'],
#  ['714', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['711', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['711', '712'],
#  ['715', '712'],
#  ['708', '712'],
#  ['707', '712'],
#  ['715', '712'],
#  ['714', '712'],
#  ['711', '708', '712'],
#  ['711', '715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['715', '712'],
#  ['870', '871'],
#  ['715', '712'],
#  ['711', '712'],
#  ['707', '712'],
#  ['708', '712'],
#  ['921', '873'],
#  ['876', '884'],
#  ['870', '871'],
#  ['921', '873'],
#  ['711', '712'],
#  ['715', '712'],
#  ['870', '871'],
#  ['715', '712'],
#  ['715', '712'],
#  ['921', '873'],
#  ['870', '871']]

# %%
df = new_df

def replace_product_names(row):
    product_ids = row["next_sequence"].split()  # Split the string into a list of product IDs
    product_names = [product_info.loc[product_info["ProductID"] == int(product_id), "ProductName"].values[0] for product_id in product_ids]
    return ", ".join(product_names)

# Apply the function to replace product IDs with product names for the "next_sequence" column
df["next_sequence"] = df.apply(replace_product_names, axis=1)

# Function to replace product IDs with product names in the list
def replace_combination_names(combination_list):
    return [product_info.loc[product_info["ProductID"] == int(product_id), "ProductName"].values[0] for product_id in combination_list]

# Apply the function to replace product IDs with product names for the "combination_from_next_sequence" column
df["combination_from_next_sequence"] = df["combination_from_next_sequence"].apply(replace_combination_names)

df
# Out:
#     productID               next_sequence  \
# 0         707                AWC Logo Cap
# 1         707      Sport-100 Helmet, Blue
# 2         707       Sport-100 Helmet, Red
# 3         707     Sport-100 Helmet, Black
# 4         707  Long-Sleeve Logo Jersey, L
# ..        ...                         ...
# 84        877       Water Bottle - 30 oz.
# 85        877                AWC Logo Cap
# 86        880                AWC Logo Cap
# 87        921         Patch Kit/8 Patches
# 88        921       Water Bottle - 30 oz.
#
#                    combination_from_next_sequence
# 0      [Long-Sleeve Logo Jersey, L, AWC Logo Cap]
# 1          [Sport-100 Helmet, Blue, AWC Logo Cap]
# 2           [Sport-100 Helmet, Red, AWC Logo Cap]
# 3         [Sport-100 Helmet, Black, AWC Logo Cap]
# 4      [Long-Sleeve Logo Jersey, L, AWC Logo Cap]
# ..                                            ...
# 84  [Water Bottle - 30 oz., Mountain Bottle Cage]
# 85     [Long-Sleeve Logo Jersey, L, AWC Logo Cap]
# 86     [Long-Sleeve Logo Jersey, L, AWC Logo Cap]
# 87      [Mountain Tire Tube, Patch Kit/8 Patches]
# 88  [Water Bottle - 30 oz., Mountain Bottle Cage]
#
# [89 rows x 3 columns]

# %%
df.to_excel('blablabl.xlsx', index=False)
